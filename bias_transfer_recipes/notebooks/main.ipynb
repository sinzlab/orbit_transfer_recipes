# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import sys
import matplotlib.pyplot as plt
import numpy as np
import os
from pathlib import Path

# %% [markdown]
# ### Load the experiment and corresponding libraries

# %%
project_path = os.path.join(Path.home(), "projects")
sys.path.append(project_path)  # enable import of "bias_transfer_recipes"
os.chdir(os.path.join(project_path,"bias_transfer_recipes/work/"))

# %%
from bias_transfer_recipes.bias_transfer_recipes.main import load_experiment
experiment = load_experiment(recipe="_2021_01_28_neurips", 
                             experiment="", 
                             schema="",  # schema name will automatically be generated from recipe and experiment names 
                             base_dir=os.path.join(project_path,"bias_transfer_recipes/bias_transfer_recipes/"),
                             import_prefix="bias_transfer_recipes.bias_transfer_recipes.", 
                             dev_mode=True  
                            )
# Out:
# Connecting anix@datajoint-db.mlcloud.uni-tuebingen.de:3306

# %%
from bias_transfer.tables.transfer import *
from bias_transfer.tables.nnfabrik import *
schema
# Out:
# Connecting anix@datajoint-db.mlcloud.uni-tuebingen.de:3306
# Schema `bias_transfer__2021_01_28_neurips`

# %%
schema.jobs
# Out:
# *table_name    *key_hash    status     key        error_message  error_stac user     host     pid     connection_id  timestamp
# +------------+ +----------+ +--------+ +--------+ +------------+ +--------+ +------+ +------+ +-----+ +------------+ +-----------+
#
#  (Total: 0)

# %%
# dElete all jobs in error state:
if schema.database != "nnfabrik_core": 
    (schema.jobs & "status='error'").delete()

# %%
# drop the entire schema: THIS IS WILL DELETE EVERYTHING!
if schema.database != "nnfabrik_core": 
    schema.drop()
# Out:
# Proceed to delete entire schema `bias_transfer_test`? [yes, No]:  yes

# %%
TransferredTrainedModel()
# Out:
# *transfer_step *model_fn      *model_hash    *dataset_fn    *dataset_hash  *trainer_fn    *trainer_hash  *seed    *collapsed_his *data_transfer comment        score     output     fabrikant_name trainedmodel_t
# +------------+ +------------+ +------------+ +------------+ +------------+ +------------+ +------------+ +------+ +------------+ +------------+ +------------+ +-------+ +--------+ +------------+ +------------+
# 0              bias_transfer. 042a7003f09597 bias_transfer. 7da0c7aae56482 bias_transfer. 23827303c0cb61 42                      0              Training ..    49.23     =BLOB=     Arne Nix       2021-02-26 01:
# 0              bias_transfer. 0719dd7f8ec84b bias_transfer. 7da0c7aae56482 bias_transfer. 15a86c093a12ba 42                      0              Training ..    42.98     =BLOB=     Arne Nix       2021-02-26 04:
# 0              bias_transfer. 0719dd7f8ec84b bias_transfer. 7da0c7aae56482 bias_transfer. e767d975de2b62 42                      0              Training ..    42.68     =BLOB=     Arne Nix       2021-02-26 03:
# 0              bias_transfer. 255438d0242149 bias_transfer. 7da0c7aae56482 bias_transfer. ef78a3112d5662 42                      0              Training ..    0.5       =BLOB=     Arne Nix       2021-02-26 01:
# 0              bias_transfer. 255438d0242149 bias_transfer. 7da0c7aae56482 bias_transfer. f1b122b27eba1d 42                      0              Training ..    43.93     =BLOB=     Arne Nix       2021-02-26 04:
# 0              bias_transfer. 4ecdc5664d8bdb bias_transfer. 4b14e63b092d62 bias_transfer. aea122e5d0eefd 42                      0              FashionMNIST D 0.0       =BLOB=     Arne Nix       2021-02-11 08:
# 0              bias_transfer. 7d1dee942e7954 bias_transfer. 7da0c7aae56482 bias_transfer. 54db162cba921e 42                      0              Training ..    42.54     =BLOB=     Arne Nix       2021-02-26 04:
# 0              bias_transfer. 7d1dee942e7954 bias_transfer. 7da0c7aae56482 bias_transfer. c61e3e01101c31 42                      0              Training ..    42.49     =BLOB=     Arne Nix       2021-02-26 03:
# 0              bias_transfer. 8791de89182ff9 bias_transfer. 65cec99007cd03 bias_transfer. 046f7c6f725057 42                      0              FashionMNIST D 0.0       =BLOB=     Arne Nix       2021-02-11 08:
# 0              bias_transfer. 96b4281cdecf8f bias_transfer. 7da0c7aae56482 bias_transfer. 716595e57a9ee1 42                      0              Training ..    39.78     =BLOB=     Arne Nix       2021-02-26 04:
# 0              bias_transfer. 96b4281cdecf8f bias_transfer. 7da0c7aae56482 bias_transfer. 8701f2152600ca 42                      0              Training ..    38.48     =BLOB=     Arne Nix       2021-02-26 03:
# 0              bias_transfer. 9f7f164cca0f06 bias_transfer. 7da0c7aae56482 bias_transfer. abfaee9143a6c8 42                      0              Training ..    43.61     =BLOB=     Arne Nix       2021-02-26 04:
#    ...
#  (Total: 64)
