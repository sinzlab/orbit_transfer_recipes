# %%
# %matplotlib inline
# %matplotlib notebook
# %load_ext autoreload
# %autoreload 2
import sys
import os
from pathlib import Path

# %% [markdown]
# ### Load the experiment and corresponding libraries

# %%
project_path = os.path.join(Path.home(), "projects")
sys.path.append(project_path)  # enable import of "bias_transfer_recipes"
os.chdir(os.path.join(project_path,"bias_transfer_recipes/work/"))

# %%
from bias_transfer_recipes.bias_transfer_recipes.main import load_experiment
experiment = load_experiment(recipe="_2021_01_28_neurips", 
                             experiment="test_path_plotting", 
                             schema="bias_transfer_test",  # schema name will automatically be generated from recipe and experiment names 
                             base_dir=os.path.join(project_path,"bias_transfer_recipes/bias_transfer_recipes/"),
                             import_prefix="bias_transfer_recipes.bias_transfer_recipes.", 
                             dev_mode=True  
                            )
# Out:
# Connecting anix@datajoint-db.mlcloud.uni-tuebingen.de:3306

# %%
from bias_transfer.tables.transfer import *
from bias_transfer.tables.nnfabrik import *
schema
# Out:
# Connecting anix@datajoint-db.mlcloud.uni-tuebingen.de:3306
# Schema `bias_transfer_test`

# %%
from bias_transfer.analysis.plot_shahd import plot_robustness
models = {
    "tin_baseline": "Baseline",
    "tin_mtl": "MTL-Monkey",
    "tin_mtl_shuffled": "MTL-Shuffled",
    "tin_mtl_simulated": "MTL-Oracle",
    "tin_oracle": "Oracle",
}
levels = [1,2,3,4,5]
noises = {
  #Noise
 'impulse_noise': {'mean': 1.1382498181175693, 'std': 0.021732717522858987},
 'shot_noise': {'mean': 1.1445938769427486, 'std': 0.03233527387562202},
 'gaussian_noise': {'mean': 1.16757326913339, 'std': 0.03459803577091069},
  #Blur
 'defocus_blur': {'mean': 1.2790867440041063, 'std': 0.06492189752606423},
 'motion_blur': {'mean': 1.1224057083895542, 'std': 0.05667087009806822},
 'zoom_blur': {'mean': 1.0998016997299138, 'std': 0.05978022484098285},
  #Weather
 'fog': {'mean': 0.8714174256698759, 'std': 0.0431492152023978},
 'frost': {'mean': 0.9393503750256575, 'std': 0.03434060817939201},
 'brightness': {'mean': 0.9670917507570457, 'std': 0.025713601780910932},
 'snow': {'mean': 1.0427817531820525, 'std': 0.03223962165426161},
  #Digital
 'elastic_transform': {'mean': 1.2250987281317924, 'std': 0.057011093727274524},
 'contrast': {'mean': 0.8666439439171599, 'std': 0.03420042371611902},
 'jpeg_compression': {'mean': 1.4733636664988563, 'std': 0.061637728118790626},
 'pixelate': {'mean': 1.6375799866244125, 'std': 0.0960530330111599},
}
noises = {k: v for k, v in sorted(noises.items(), key=lambda item: item[1]["mean"])}
# print(noises)
noises = list(noises.keys())

noise_grouping = {"Noise": [ 'impulse_noise', 'shot_noise', 'gaussian_noise',],
                  "Blur": [ 'defocus_blur', 'motion_blur', 'zoom_blur',],
                  "Weather":[ 'fog', 'frost', 'brightness',],
                  "Digital":[ 'elastic_transform', 'contrast', 'jpeg_compression', 'pixelate',]
                 }

plot_robustness(models=list(models.keys()), folder_name='real_data_workshop', test_set='c', levels=levels, name_map = models,
#                 noises=[noises[13],noises[6],noises[0]],
                noises=noises, noise_grouping=noise_grouping,
                plot_individual=False, plot_per_noise_robustness=True, plot_overview=True, plot_correlation=True,
                style="iclr_paper_tex", legend_outside=False, title="", x_label="", y_label="",
               rotate_x_labels=False, despine=False, save="bars_scatter", nrows=1, ncols=3, panel_labels=True,
               figure_height_scale=0.45,
               fraction=0.92, sharey=False,
                gridspec_kw={'width_ratios': [12, 4, 8]}
               )
# Out:
# ROBUST {'5': {'scores': [1.0605293047024886, 1.3214304158457355, 1.1959688403786617, 1.1668994772265973, 1.0515076560607084], 'neural': [0.93360525, 0.93518025, 0.93422383, 0.9351331, 0.9364979], 'mean_cls': [43.9, 46.67, 45.69, 45.03, 44.8]}, '4': {'scores': [1.0581930981477947, 1.1703586921264721, 1.13102496829457, 1.2134384435475114, 1.0361691220618963], 'neural': [0.9373317, 0.9369268, 0.93741256, 0.938035, 0.93919057], 'mean_cls': [42.93, 44.02, 43.49, 45.42, 45.68]}, '3': {'scores': [1.0891912938380504, 1.1858299126916871, 1.2163932104244028, 1.1837584138730255, 0.9689009739291906], 'neural': [0.93884426, 0.936591, 0.9402035, 0.9368704, 0.9369564], 'mean_cls': [43.45, 45.3, 45.05, 45.74, 42.33]}, '2': {'scores': [1.2059505856480957, 1.2393312471486748, 1.2038282422595312, 1.1764539195217565, 0.9821622752190411], 'neural': [0.9367397, 0.9366818, 0.9378444, 0.936091, 0.9358795], 'mean_cls': [47.86, 46.49, 45.08, 44.82, 43.36]}, '1': {'scores': [1.2100349408110442, 1.1535148983934
# ...

# %%
from bias_transfer.analysis.plot_shahd import plot_robustness
models = {
    "tin_baseline": "Baseline",
    "tin_mtl": "MTL-Monkey",
    "tin_mtl_shuffled": "MTL-Shuffled",
    "tin_mtl_simulated": "MTL-Oracle",
    "tin_oracle": "Oracle",
}
levels = [1,2,3,4,5]
noises = {
  #Noise
 'impulse_noise': {'mean': 1.1382498181175693, 'std': 0.021732717522858987},
 'shot_noise': {'mean': 1.1445938769427486, 'std': 0.03233527387562202},
 'gaussian_noise': {'mean': 1.16757326913339, 'std': 0.03459803577091069},
  #Blur
 'defocus_blur': {'mean': 1.2790867440041063, 'std': 0.06492189752606423},
 'motion_blur': {'mean': 1.1224057083895542, 'std': 0.05667087009806822},
 'zoom_blur': {'mean': 1.0998016997299138, 'std': 0.05978022484098285},
  #Weather
 'fog': {'mean': 0.8714174256698759, 'std': 0.0431492152023978},
 'frost': {'mean': 0.9393503750256575, 'std': 0.03434060817939201},
 'brightness': {'mean': 0.9670917507570457, 'std': 0.025713601780910932},
 'snow': {'mean': 1.0427817531820525, 'std': 0.03223962165426161},
  #Digital
 'elastic_transform': {'mean': 1.2250987281317924, 'std': 0.057011093727274524},
 'contrast': {'mean': 0.8666439439171599, 'std': 0.03420042371611902},
 'jpeg_compression': {'mean': 1.4733636664988563, 'std': 0.061637728118790626},
 'pixelate': {'mean': 1.6375799866244125, 'std': 0.0960530330111599},
}
noises = {k: v for k, v in sorted(noises.items(), key=lambda item: item[1]["mean"])}
# print(noises)
noises = list(noises.keys())

noise_grouping = {"Noise": [ 'impulse_noise', 'shot_noise', 'gaussian_noise',],
                  "Blur": [ 'defocus_blur', 'motion_blur', 'zoom_blur',],
                  "Weather":[ 'fog', 'frost', 'brightness',],
                  "Digital":[ 'elastic_transform', 'contrast', 'jpeg_compression', 'pixelate',]
                 }

plot_robustness(models=list(models.keys()), folder_name='real_data_workshop', test_set='c', levels=levels, name_map = models,
#                 noises=[noises[13],noises[6],noises[0]],
                noises=noises, noise_grouping=noise_grouping,
                plot_individual=True, plot_per_noise_robustness=True, add_overview_to_groups=True,
                style="iclr_paper_tex", legend_outside=False, title="", x_label="", y_label="",
               rotate_x_labels=False, despine=False, save="per_noise_robustness", nrows=1, ncols=3, panel_labels=True,
               figure_height_scale=0.52,
               fraction=1.0
               )
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-34-f4e84847e2c6> in <module>
#      38                  }
#      39
# ---> 40 plot_robustness(models=list(models.keys()), folder_name='real_data_workshop', test_set='c', levels=levels, name_map = models,
#      41 #                 noises=[noises[13],noises[6],noises[0]],
#      42                 noises=noises, noise_grouping=noise_grouping,
#
# ~/projects/bias_transfer/bias_transfer/analysis/plot_shahd.py in plot_robustness(models, folder_name, test_set, levels, std, name_map, noises, noise_grouping, plot_overview, plot_correlation, plot_correlation_bootstrapped, plot_individual, plot_per_noise_robustness, add_overview_to_groups, **kwargs)
#     198         if add_overview_to_groups and per_noise_data:
#     199             for model, results in overview_data.items():
# ...

# %%
from bias_transfer.analysis.plot_shahd import plot_robustness
models = {
    "tin_baseline": "Baseline",
    "tin_mtl": "MTL-Monkey",
    "tin_mtl_shuffled": "MTL-Shuffled",
    "tin_oracle": "Oracle",
    "tin_mtl_simulated": "MTL-Oracle",
}
levels = [1,2,3,4,5]
noises = {'contrast': {'mean': 0.8666439439171599, 'std': 0.03420042371611902},
 'fog': {'mean': 0.8714174256698759, 'std': 0.0431492152023978},
 'frost': {'mean': 0.9393503750256575, 'std': 0.03434060817939201},
 'brightness': {'mean': 0.9670917507570457, 'std': 0.025713601780910932},
 'snow': {'mean': 1.0427817531820525, 'std': 0.03223962165426161},
 'zoom_blur': {'mean': 1.0998016997299138, 'std': 0.05978022484098285},
 'motion_blur': {'mean': 1.1224057083895542, 'std': 0.05667087009806822},
 'impulse_noise': {'mean': 1.1382498181175693, 'std': 0.021732717522858987},
 'shot_noise': {'mean': 1.1445938769427486, 'std': 0.03233527387562202},
 'gaussian_noise': {'mean': 1.16757326913339, 'std': 0.03459803577091069},
 'elastic_transform': {'mean': 1.2250987281317924,
  'std': 0.057011093727274524},
 'defocus_blur': {'mean': 1.2790867440041063, 'std': 0.06492189752606423},
 'jpeg_compression': {'mean': 1.4733636664988563, 'std': 0.061637728118790626},
 'pixelate': {'mean': 1.6375799866244125, 'std': 0.0960530330111599}}
noises = {k: v for k, v in sorted(noises.items(), key=lambda item: item[1]["mean"])}
print(noises)
noises = list(noises.keys())

plot_robustness(models=list(models.keys()), folder_name='real_data_workshop', test_set='c', levels=levels, name_map = models,
#                 noises=[noises[13],noises[6],noises[0]],
                noises=noises,
                style="iclr_paper_tex", legend_outside=False, title="", x_label="", y_label="",
               rotate_x_labels=False, despine=True, save="individual", nrows=1, ncols=3, panel_labels=False,
               figure_height_scale=0.5, fraction=0.86, sharey=True, sharex=True)
# Out:
# {'contrast': {'mean': 0.8666439439171599, 'std': 0.03420042371611902}, 'fog': {'mean': 0.8714174256698759, 'std': 0.0431492152023978}, 'frost': {'mean': 0.9393503750256575, 'std': 0.03434060817939201}, 'brightness': {'mean': 0.9670917507570457, 'std': 0.025713601780910932}, 'snow': {'mean': 1.0427817531820525, 'std': 0.03223962165426161}, 'zoom_blur': {'mean': 1.0998016997299138, 'std': 0.05978022484098285}, 'motion_blur': {'mean': 1.1224057083895542, 'std': 0.05667087009806822}, 'impulse_noise': {'mean': 1.1382498181175693, 'std': 0.021732717522858987}, 'shot_noise': {'mean': 1.1445938769427486, 'std': 0.03233527387562202}, 'gaussian_noise': {'mean': 1.16757326913339, 'std': 0.03459803577091069}, 'elastic_transform': {'mean': 1.2250987281317924, 'std': 0.057011093727274524}, 'defocus_blur': {'mean': 1.2790867440041063, 'std': 0.06492189752606423}, 'jpeg_compression': {'mean': 1.4733636664988563, 'std': 0.061637728118790626}, 'pixelate': {'mean': 1.6375799866244125, 'std': 0.09605303
# ...

# %%
plot_robustness(models=list(models.keys()), folder_name='real_data_workshop', test_set='c', levels=levels, name_map = models,
                noises=noises,  plot_overview=True, plot_individual=False, plot_correlation=True,
                style="iclr_paper_tex", legend_outside=False, title="", x_label="", y_label="",
               rotate_x_labels=False, despine=False, save="overview", nrows=1, ncols=2, panel_labels=True,
                fraction=0.66, figure_height_scale = 0.8
               )
# Out:
# ROBUST {'5': {'scores': [1.0605293047024886, 1.3214304158457355, 1.1959688403786617, 1.1668994772265973, 1.0515076560607084], 'neural': [0.93360525, 0.93518025, 0.93422383, 0.9351331, 0.9364979], 'mean_cls': [43.9, 46.67, 45.69, 45.03, 44.8]}, '4': {'scores': [1.0581930981477947, 1.1703586921264721, 1.13102496829457, 1.2134384435475114, 1.0361691220618963], 'neural': [0.9373317, 0.9369268, 0.93741256, 0.938035, 0.93919057], 'mean_cls': [42.93, 44.02, 43.49, 45.42, 45.68]}, '3': {'scores': [1.0891912938380504, 1.1858299126916871, 1.2163932104244028, 1.1837584138730255, 0.9689009739291906], 'neural': [0.93884426, 0.936591, 0.9402035, 0.9368704, 0.9369564], 'mean_cls': [43.45, 45.3, 45.05, 45.74, 42.33]}, '2': {'scores': [1.2059505856480957, 1.2393312471486748, 1.2038282422595312, 1.1764539195217565, 0.9821622752190411], 'neural': [0.9367397, 0.9366818, 0.9378444, 0.936091, 0.9358795], 'mean_cls': [47.86, 46.49, 45.08, 44.82, 43.36]}, '1': {'scores': [1.2100349408110442, 1.1535148983934
# ...

# %%
plot_robustness(models=list(models.keys()), folder_name='real_data_workshop', test_set='c', levels=levels, name_map = models,
                noises=noises,  plot_overview=False, plot_individual=False, plot_correlation=True,
                style="iclr_paper_tex", legend_outside=False, title="", x_label="", y_label="",
               rotate_x_labels=False, despine=True, save="correlation", nrows=1, ncols=1, panel_labels=False,
                fraction=0.33
               )
# Out:
# ROBUST {'5': {'scores': [1.0605293047024886, 1.3214304158457355, 1.1959688403786617, 1.1668994772265973, 1.0515076560607084], 'neural': [0.93360525, 0.93518025, 0.93422383, 0.9351331, 0.9364979], 'mean_cls': [43.9, 46.67, 45.69, 45.03, 44.8]}, '4': {'scores': [1.0581930981477947, 1.1703586921264721, 1.13102496829457, 1.2134384435475114, 1.0361691220618963], 'neural': [0.9373317, 0.9369268, 0.93741256, 0.938035, 0.93919057], 'mean_cls': [42.93, 44.02, 43.49, 45.42, 45.68]}, '3': {'scores': [1.0891912938380504, 1.1858299126916871, 1.2163932104244028, 1.1837584138730255, 0.9689009739291906], 'neural': [0.93884426, 0.936591, 0.9402035, 0.9368704, 0.9369564], 'mean_cls': [43.45, 45.3, 45.05, 45.74, 42.33]}, '2': {'scores': [1.2059505856480957, 1.2393312471486748, 1.2038282422595312, 1.1764539195217565, 0.9821622752190411], 'neural': [0.9367397, 0.9366818, 0.9378444, 0.936091, 0.9358795], 'mean_cls': [47.86, 46.49, 45.08, 44.82, 43.36]}, '1': {'scores': [1.2100349408110442, 1.1535148983934
# ...

# %%
data={'tin_mtl': {'impulse_noise': {'mean': 1.1382498181175693,
   'std': 0.021732717522858987},
  'shot_noise': {'mean': 1.1445938769427486, 'std': 0.03233527387562202},
  'gaussian_noise': {'mean': 1.16757326913339, 'std': 0.03459803577091069},
  'snow': {'mean': 1.0427817531820525, 'std': 0.03223962165426161},
  'jpeg_compression': {'mean': 1.4733636664988563,
   'std': 0.061637728118790626},
  'contrast': {'mean': 0.8666439439171599, 'std': 0.03420042371611902},
  'fog': {'mean': 0.8714174256698759, 'std': 0.0431492152023978},
  'defocus_blur': {'mean': 1.2790867440041063, 'std': 0.06492189752606423},
  'frost': {'mean': 0.9393503750256575, 'std': 0.03434060817939201},
  'pixelate': {'mean': 1.6375799866244125, 'std': 0.0960530330111599},
  'motion_blur': {'mean': 1.1224057083895542, 'std': 0.05667087009806822},
  'zoom_blur': {'mean': 1.0998016997299138, 'std': 0.05978022484098285},
  'brightness': {'mean': 0.9670917507570457, 'std': 0.025713601780910932},
  'elastic_transform': {'mean': 1.2250987281317924,
   'std': 0.057011093727274524}},
 'tin_mtl_simulated': {'impulse_noise': {'mean': 1.289175920852348,
   'std': 0.02727668254693712},
  'shot_noise': {'mean': 1.1837546995145647, 'std': 0.03319951886544033},
  'gaussian_noise': {'mean': 1.2102207121308757, 'std': 0.03874440616945163},
  'snow': {'mean': 1.2001704132382043, 'std': 0.03544684540844301},
  'jpeg_compression': {'mean': 1.2527861435268393, 'std': 0.06293125727925093},
  'contrast': {'mean': 1.256430305108675, 'std': 0.05804013233174972},
  'fog': {'mean': 1.2416551433504388, 'std': 0.06717001378653055},
  'defocus_blur': {'mean': 1.065835346486067, 'std': 0.08324537399036161},
  'frost': {'mean': 1.167119351366799, 'std': 0.03689185588217139},
  'pixelate': {'mean': 1.4496265189765178, 'std': 0.08865065325098238},
  'motion_blur': {'mean': 1.2112232623961972, 'std': 0.06199623379571599},
  'zoom_blur': {'mean': 1.179691572119581, 'std': 0.06327814190188231},
  'brightness': {'mean': 1.0690119549843684, 'std': 0.027333564313928808},
  'elastic_transform': {'mean': 1.2674201532967897,
   'std': 0.062267346451249615}},
 'tin_oracle': {'impulse_noise': {'mean': 1.360186931178684,
   'std': 0.034363865073652876},
  'shot_noise': {'mean': 1.1918544017946695, 'std': 0.028887258158134168},
  'gaussian_noise': {'mean': 1.196348859539709, 'std': 0.029185015410017803},
  'snow': {'mean': 1.257592109322202, 'std': 0.03232127159994839},
  'jpeg_compression': {'mean': 1.4021578910957435,
   'std': 0.055621541075757334},
  'contrast': {'mean': 1.381197134083414, 'std': 0.06524536936496758},
  'fog': {'mean': 1.2311698171933712, 'std': 0.06348887899669996},
  'defocus_blur': {'mean': 0.9963865095763499, 'std': 0.03988720661516233},
  'frost': {'mean': 1.2064572447890933, 'std': 0.03376639650138054},
  'pixelate': {'mean': 1.5919314301245517, 'std': 0.0948499113754335},
  'motion_blur': {'mean': 1.0781558396789965, 'std': 0.05056732500567591},
  'zoom_blur': {'mean': 1.2235020039717364, 'std': 0.06404636192682987},
  'brightness': {'mean': 1.112679017832827, 'std': 0.02533030955941799},
  'elastic_transform': {'mean': 1.094990981826949,
   'std': 0.04077137103937562}},
 'tin_mtl_shuffled': {'impulse_noise': {'mean': 0.9091203262075771,
   'std': 0.010690535459664436},
  'shot_noise': {'mean': 0.8715188742916928, 'std': 0.018583223698406853},
  'gaussian_noise': {'mean': 0.8887472782202346, 'std': 0.02016555886078666},
  'snow': {'mean': 0.9577235854312844, 'std': 0.02388953893716707},
  'jpeg_compression': {'mean': 0.9566981404216731, 'std': 0.03930616530213951},
  'contrast': {'mean': 0.9329800957098847, 'std': 0.037786180537321294},
  'fog': {'mean': 1.0293269740487963, 'std': 0.04914966538024458},
  'defocus_blur': {'mean': 1.0358094871292765, 'std': 0.0342379034848434},
  'frost': {'mean': 0.8871953485798814, 'std': 0.025113127028805207},
  'pixelate': {'mean': 0.8943242418215404, 'std': 0.05014348497671741},
  'motion_blur': {'mean': 1.0561203308718707, 'std': 0.052523481426975535},
  'zoom_blur': {'mean': 0.9622606004730606, 'std': 0.04750526595964813},
  'brightness': {'mean': 0.9323910510621174, 'std': 0.019873234181778075},
  'elastic_transform': {'mean': 1.1717202797328319,
   'std': 0.04196839879030672}},
 'tin_baseline': {'impulse_noise': {'mean': 1.0, 'std': 0.0},
  'shot_noise': {'mean': 1.0, 'std': 0.0},
  'gaussian_noise': {'mean': 1.0, 'std': 0.0},
  'snow': {'mean': 1.0, 'std': 0.0},
  'jpeg_compression': {'mean': 1.0, 'std': 0.0},
  'contrast': {'mean': 1.0, 'std': 0.0},
  'fog': {'mean': 1.0, 'std': 0.0},
  'defocus_blur': {'mean': 1.0, 'std': 0.0},
  'frost': {'mean': 1.0, 'std': 0.0},
  'pixelate': {'mean': 1.0, 'std': 0.0},
  'motion_blur': {'mean': 1.0, 'std': 0.0},
  'zoom_blur': {'mean': 1.0, 'std': 0.0},
  'brightness': {'mean': 1.0, 'std': 0.0},
  'elastic_transform': {'mean': 1.0, 'std': 0.0}}}

# %%
import json

with open('robust_scores_per_noise.json', 'w') as fp:
    json.dump(data, fp)

# %%
x ={'figure': <Figure size 396x127.266 with 3 Axes>, '_subplotspec': GridSpec(1, 3)[0:1, 2:3], 'figbox': Bbox([[0.723115649568302, 0.29326269607395905], [0.9590135469486535, 0.8134260298640609]]), 'numRows': 1, 'numCols': 3, '_stale': True, 'stale_callback': <function _stale_figure_callback at 0x7f6753932b80>, '_axes': <AxesSubplot:xlabel='Corruption', ylabel='Robustness'>, '_transform': None, '_transformSet': False, '_visible': True, '_animated': False, '_alpha': None, 'clipbox': None, '_clippath': None, '_clipon': True, '_label': '', '_picker': None, '_contains': None, '_rasterized': None, '_agg_filter': None, '_mouseover': False, 'eventson': False, '_oid': 0, '_propobservers': {}, '_remove_method': <bound method Figure.delaxes of <Figure size 396x127.266 with 3 Axes>>, '_url': None, '_gid': None, '_snap': None, '_sketch': None, '_path_effects': [], '_sticky_edges': _XYPair(x=[], y=[]), '_in_layout': True, '_position': Bbox([[0.723115649568302, 0.29326269607395905], [0.9590135469486535, 0.8134260298640609]]), '_originalPosition': Bbox([[0.723115649568302, 0.29326269607395905], [0.9590135469486535, 0.8134260298640609]]), '_aspect': 'auto', '_adjustable': 'box', '_anchor': 'C', '_stale_viewlim_x': False, '_stale_viewlim_y': False, '_sharex': None, '_sharey': None, 'bbox': <matplotlib.transforms.TransformedBbox object at 0x7f676b7c4760>, 'dataLim': Bbox([[-0.4, 0.0], [4.4, 143.46691440058126]]), '_viewLim': Bbox([[-0.5, 0.0], [4.5, 150.64026012061032]]), 'transScale': <matplotlib.transforms.TransformWrapper object at 0x7f676b7c45b0>, 'transAxes': <matplotlib.transforms.BboxTransformTo object at 0x7f676b7c4970>, 'transLimits': <matplotlib.transforms.BboxTransformFrom object at 0x7f676b7c48b0>, 'transData': <matplotlib.transforms.CompositeGenericTransform object at 0x7f676b7c4f70>, '_xaxis_transform': <matplotlib.transforms.BlendedGenericTransform object at 0x7f676b7c4be0>, '_yaxis_transform': <matplotlib.transforms.BlendedGenericTransform object at 0x7f676b7c4850>, '_box_aspect': None, '_axes_locator': None, 'spines': OrderedDict([('left', <matplotlib.spines.Spine object at 0x7f676b7c4700>), ('right', <matplotlib.spines.Spine object at 0x7f676b7c4430>), ('bottom', <matplotlib.spines.Spine object at 0x7f676b7c43d0>), ('top', <matplotlib.spines.Spine object at 0x7f676b7c4a60>)]), 'xaxis': <matplotlib.axis.XAxis object at 0x7f676b7c4910>, 'yaxis': <matplotlib.axis.YAxis object at 0x7f676b7c4c40>, '_facecolor': 'white', '_frameon': True, '_axisbelow': True, '_rasterization_zorder': None, 'ignore_existing_data_limits': False, 'callbacks': <matplotlib.cbook.CallbackRegistry object at 0x7f676b7c48e0>, '_autoscaleXon': True, '_autoscaleYon': True, '_xmargin': 0.05, '_ymargin': 0.05, '_tight': None, '_use_sticky_edges': True, '_get_lines': <matplotlib.axes._base._process_plot_var_args object at 0x7f676b7c4dc0>, '_get_patches_for_fill': <matplotlib.axes._base._process_plot_var_args object at 0x7f66d3ae0df0>, '_gridOn': True, 'lines': [<matplotlib.lines.Line2D object at 0x7f676b792c40>, <matplotlib.lines.Line2D object at 0x7f676b4568b0>, <matplotlib.lines.Line2D object at 0x7f676b456b80>, <matplotlib.lines.Line2D object at 0x7f676b456ee0>, <matplotlib.lines.Line2D object at 0x7f676b468280>, <matplotlib.lines.Line2D object at 0x7f676b4685e0>, <matplotlib.lines.Line2D object at 0x7f676b446730>, <matplotlib.lines.Line2D object at 0x7f676b446b20>, <matplotlib.lines.Line2D object at 0x7f676b446e80>, <matplotlib.lines.Line2D object at 0x7f676b307220>, <matplotlib.lines.Line2D object at 0x7f676b307580>, <matplotlib.lines.Line2D object at 0x7f676b31a6a0>, <matplotlib.lines.Line2D object at 0x7f676b31aa90>, <matplotlib.lines.Line2D object at 0x7f676b31adf0>, <matplotlib.lines.Line2D object at 0x7f66d39be1c0>, <matplotlib.lines.Line2D object at 0x7f66d39be520>, <matplotlib.lines.Line2D object at 0x7f66d39c4610>, <matplotlib.lines.Line2D object at 0x7f66d39c4a00>, <matplotlib.lines.Line2D object at 0x7f66d39c4d60>, <matplotlib.lines.Line2D object at 0x7f66d39e0100>, <matplotlib.lines.Line2D object at 0x7f66d39e0460>], 'patches': [<matplotlib.patches.Rectangle object at 0x7f676b7dcf40>, <matplotlib.patches.Rectangle object at 0x7f676b7b2ac0>, <matplotlib.patches.Rectangle object at 0x7f676b1cadf0>, <matplotlib.patches.Rectangle object at 0x7f676b4561c0>, <matplotlib.patches.Rectangle object at 0x7f676b456490>, <matplotlib.patches.Rectangle object at 0x7f676b468970>, <matplotlib.patches.Rectangle object at 0x7f676b7b2a90>, <matplotlib.patches.Rectangle object at 0x7f676b468e80>, <matplotlib.patches.Rectangle object at 0x7f676b446190>, <matplotlib.patches.Rectangle object at 0x7f676b446460>, <matplotlib.patches.Rectangle object at 0x7f676b307910>, <matplotlib.patches.Rectangle object at 0x7f676b4688b0>, <matplotlib.patches.Rectangle object at 0x7f676b307df0>, <matplotlib.patches.Rectangle object at 0x7f676b31a100>, <matplotlib.patches.Rectangle object at 0x7f676b31a3d0>, <matplotlib.patches.Rectangle object at 0x7f66d39be8b0>, <matplotlib.patches.Rectangle object at 0x7f676b307850>, <matplotlib.patches.Rectangle object at 0x7f66d39bed60>, <matplotlib.patches.Rectangle object at 0x7f66d39c4070>, <matplotlib.patches.Rectangle object at 0x7f66d39c4340>], 'texts': [], 'tables': [], 'artists': [], 'images': [], '_mouseover_set': <matplotlib.cbook._OrderedSet object at 0x7f66d3ae0d30>, 'child_axes': [], '_current_image': None, 'legend_': <matplotlib.legend.Legend object at 0x7f66d3b3c070>, 'collections': [], 'containers': [<BarContainer object of 5 artists>, <BarContainer object of 5 artists>, <BarContainer object of 5 artists>, <BarContainer object of 5 artists>], '_autotitlepos': True, 'title': Text(0.5, 1.0, ''), '_left_title': Text(0.0, 1.0, ''), '_right_title': Text(1.0, 1.0, ''), 'titleOffsetTrans': <matplotlib.transforms.ScaledTranslation object at 0x7f676ae32f40>, 'patch': <matplotlib.patches.Rectangle object at 0x7f676ae32100>, 'axison': True, 'fmt_xdata': None, 'fmt_ydata': None, '_navigate': True, '_navigate_mode': None, '_xcid': 0, '_ycid': 0, '_layoutbox': None, '_poslayoutbox': None}
# Out:
#   File "<ipython-input-31-b7430ddf5278>", line 1
# ...
